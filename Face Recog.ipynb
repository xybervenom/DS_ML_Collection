# %%
import os

# %%
os.chdir(r'C:\Users\devan\machine learning data\FaceRecognition-master')

# %%
import cv2
import numpy as np
import os
import faceRecognition as fr

# %%
face_classifier=cv2.CascadeClassifier("haarcascade_frontalface_Default.xml")

# %%
import cv2
import os
import numpy as np


#Given an image below function returns rectangle for face detected alongwith gray scale image
def faceDetection(test_img):
    gray_img=cv2.cvtColor(test_img,cv2.COLOR_BGR2GRAY)#convert color image to grayscale
    face_haar_cascade=cv2.CascadeClassifier('HaarCascade/haarcascade_frontalface_default.xml')#Load haar classifier
    faces=face_haar_cascade.detectMultiScale(gray_img,scaleFactor=1.32,minNeighbors=5)#detectMultiScale returns rectangles

    return faces,gray_img

# %%
test_img=cv2.imread('TestImages/devansh.jpeg')#test_img path
faces_detected,gray_img=fr.faceDetection(test_img)
print("faces_detected:",faces_detected)

for (x,y,w,h) in faces_detected:
    cv2.rectangle(test_img,(x,y),(x+w,y+h),(255,0,0),thickness=5)
resized_img=cv2.resize(test_img,(1000,1000))
cv2.imshow("face dtecetion tutorial",resized_img)
cv2.waitKey(0)#Waits indefinitely until a key is pressed
cv2.destroyAllWindows
# Out:
# faces_detected: [[ 78 302 509 509]]
# <function destroyAllWindows>

# %%
#Given a directory below function returns part of gray_img which is face alongwith its label/ID
def labels_for_training_data(directory):
    faces=[]
    faceID=[]

    for path,subdirnames,filenames in os.walk(directory):
        for filename in filenames:
            if filename.startswith("."):
                print("Skipping system file")#Skipping files that startwith .
                continue

            id=os.path.basename(path)#fetching subdirectory names
            img_path=os.path.join(path,filename)#fetching image path
            print("img_path:",img_path)
            print("id:",id)
            test_img=cv2.imread(img_path)#loading each image one by one
            if test_img is None:
                print("Image not loaded properly")
                continue
            faces_rect,gray_img=faceDetection(test_img)#Calling faceDetection function to return faces detected in particular image
            if len(faces_rect)!=1:
               continue #Since we are assuming only single person images are being fed to classifier
            (x,y,w,h)=faces_rect[0]
            roi_gray=gray_img[y:y+w,x:x+h]#cropping region of interest i.e. face area from grayscale image
            faces.append(roi_gray)
            faceID.append(int(id))
    return faces,faceID


#Below function trains haar classifier and takes faces,faceID returned by previous function as its arguments
def train_classifier(faces,faceID):
    face_recognizer=cv2.face.LBPHFaceRecognizer_create()
    face_recognizer.train(faces,np.array(faceID))
    return face_recognizer

#Below function draws bounding boxes around detected face in image
def draw_rect(test_img,face):
    (x,y,w,h)=face
    cv2.rectangle(test_img,(x,y),(x+w,y+h),(255,0,0),thickness=5)

#Below function writes name of person for detected label
def put_text(test_img,text,x,y):
    cv2.putText(test_img,text,(x,y),cv2.FONT_HERSHEY_DUPLEX,2,(255,0,0),4)

test_img=cv2.imread('TestImages/devansh.jpeg')#test_img path
faces_detected,gray_img=fr.faceDetection(test_img)
print("faces_detected:",faces_detected)

#Comment belows lines when running this program second time.Since it saves training.yml file in directory
faces,faceID=fr.labels_for_training_data('trainingImages')
face_recognizer=fr.train_classifier(faces,faceID)

name={0:"chetan",1:"devansh",2:"kshitij",3:"suryansh",4:"yogesh"}#creating dictionary containing names for each label

for face in faces_detected:
    (x,y,w,h)=face
    roi_gray=gray_img[y:y+h,x:x+h]
    label,confidence=face_recognizer.predict(roi_gray)#predicting the label of given image
    print("confidence:",confidence)
    print("label:",label)
    fr.draw_rect(test_img,face)
    predicted_name=name[label]
    if(confidence>37):#If confidence more than 37 then don't print predicted face text on screen
        continue
    fr.put_text(test_img,predicted_name,x,y)
# Out:
# faces_detected: [[ 78 302 509 509]]
# img_path: trainingImages\0\chetan.jpeg
# id: 0
# img_path: trainingImages\1\devansh.jpeg
# id: 1
# img_path: trainingImages\1\WhatsApp Image 2020-07-05 at 01.42.14.jpeg
# id: 1
# img_path: trainingImages\2\kshitij.jpeg
# id: 2
# img_path: trainingImages\2\son.jpeg
# id: 2
# img_path: trainingImages\3\suryansh.jpeg
# id: 3
# img_path: trainingImages\4\yogesh.jpeg
# id: 4
# confidence: 0.0
# label: 1

# %%
resized_img=cv2.resize(test_img,(1000,1000))
cv2.imshow("face dtecetion tutorial",resized_img)
cv2.waitKey(0)#Waits indefinitely until a key is pressed
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %%
import faceRecognition as fr

# %%
face_recognizer = cv2.face.LBPHFaceRecognizer_create()
face_recognizer.read('trainingData.yml')#Load saved training data

name = {0:"chetan",1:"devansh",2:"kshitij",3:"suryansh",4:"yogesh"}


cap=cv2.VideoCapture(0)

while True:
    ret,test_img=cap.read()# captures frame and returns boolean value and captured image
    faces_detected,gray_img=fr.faceDetection(test_img)



    for (x,y,w,h) in faces_detected:
      cv2.rectangle(test_img,(x,y),(x+w,y+h),(255,0,0),thickness=7)

    resized_img = cv2.resize(test_img, (1000, 700))
    cv2.imshow('face detection Tutorial ',resized_img)
    cv2.waitKey(10)


    for face in faces_detected:
        (x,y,w,h)=face
        roi_gray=gray_img[y:y+w, x:x+h]
        label,confidence=face_recognizer.predict(roi_gray)#predicting the label of given image
        print("confidence:",confidence)
        print("label:",label)
        fr.draw_rect(test_img,face)
        predicted_name=name[label]
        if confidence > 39:#If confidence less than 37 then don't print predicted face text on screen
           fr.put_text(test_img,predicted_name,x,y)


    resized_img = cv2.resize(test_img, (1000, 700))
    cv2.imshow('face recognition tutorial ',resized_img)
    if cv2.waitKey(1) & 0xff==ord('q'):#wait until 'q' key is pressed
        break


cap.release()
cv2.destroyAllWindows
# Out:
# confidence: 57.37011569426947
# label: 0
# confidence: 55.65559491409467
# label: 0
# confidence: 58.6895198271402
# label: 0
# confidence: 59.006107647035215
# label: 0
# confidence: 59.83146411517288
# label: 0
# confidence: 56.1166758945394
# label: 0
# confidence: 53.44262214251817
# label: 0
# confidence: 54.58122068616955
# label: 0
# confidence: 54.17834222724893
# label: 0
# confidence: 54.2741074884085
# label: 0
# confidence: 64.31871817331262
# label: 0
# confidence: 64.84041883785659
# label: 0
# confidence: 62.16233276334959
# label: 0
# confidence: 62.32395035238597
# label: 0
# confidence: 63.503350610862086
# label: 0
# confidence: 63.07219087154983
# label: 0
# confidence: 60.700584504159124
# label: 0
# confidence: 61.844960124920576
# label: 0
# confidence: 61.657793149597055
# label: 0
# confidence: 63.36341345595882
# label: 0
# confidence: 62.472295237704756
# label: 0
# confidence: 62.112941630255754
# label: 0
# confidence: 62.98959808874293
# label: 0
# confidence: 61.03472960688026
# label: 0
# confidence: 60.965950288103606
# label: 0
# confidence: 61.40473269728957
# label: 0
# confidence: 62.41616994233127
# label: 0
# confidence: 60.97005559137112
# label: 0
# confidence: 61.756044202738074
# label: 0
# confidence: 64.199514556709
# label: 0
# confidence: 62.57509018051444
# label: 0
# confidence: 64.41664132609142
# label: 0
# confidence: 64.48193035165605
# label: 0
# confidence: 62.8036344451636
# label: 0
# confidence: 63.19669460101922
# label: 0
# confidence: 63.16572782659455
# label: 0
# confidence: 63.520671920871536
# label: 0
# confidence: 63.139649901047804
# label: 0
# confidence: 64.58084939347442
# label: 0
# confidence: 62.69305399516371
# label: 0
# confidence: 62.7940631805882
# label: 0
# confidence: 60.511319660636005
# label: 0
# confidence: 61.35539108383165
# label: 0
# confidence: 63.90493635175402
# label: 0
# confidence: 63.96439620746291
# label: 0
# confidence: 63.19572914321084
# label: 0
# confidence: 63.33524588591718
# label: 0
# confidence: 60.70778897897116
# label: 0
# confidence: 63.50330178552753
# label: 0
# confidence: 63.10781190054369
# label: 0
# confidence: 64.26450986067421
# label: 0
# confidence: 64.73887234063
# label: 0
# confidence: 64.28813952978655
# label: 0
# confidence: 64.04554548999369
# label: 0
# confidence: 67.33582840174049
# label: 0
# confidence: 64.29916896287456
# label: 0
# confidence: 63.61045461809422
# label: 0
# confidence: 66.82079926324775
# label: 0
# confidence: 65.78222167292994
# label: 0
# confidence: 65.72517689787047
# label: 0
# confidence: 65.29414794716986
# label: 0
# confidence: 64.54521325790289
# label: 0
# confidence: 65.28534209786979
# label: 0
# confidence: 66.41071112247758
# label: 0
# confidence: 64.95205119905218
# label: 0
# confidence: 64.71435605324702
# label: 0
# confidence: 63.32955854548418
# label: 0
# confidence: 64.08946541877424
# label: 0
# confidence: 64.57867625689374
# label: 0
# confidence: 65.2604136311573
# label: 0
# confidence: 65.55200201111506
# label: 0
# confidence: 64.67811636926812
# label: 0
# confidence: 65.31241063999451
# label: 0
# confidence: 64.15069600256064
# label: 0
# confidence: 62.76633388173066
# label: 0
# confidence: 64.26181697906408
# label: 0
# confidence: 63.05887117732005
# label: 0
# confidence: 62.22255076099664
# label: 0
# confidence: 62.44180930781566
# label: 0
# confidence: 61.81463788921319
# label: 0
# confidence: 62.14093038925658
# label: 0
# confidence: 64.56973584659691
# label: 0
# confidence: 62.774548353512806
# label: 0
# confidence: 63.754394455982776
# label: 0
# confidence: 62.91207415211541
# label: 0
# confidence: 62.743196393995056
# label: 0
# confidence: 64.40042363471635
# label: 0
# confidence: 62.34581913974393
# label: 0
# confidence: 63.83321530239999
# label: 0
# confidence: 63.59662326049583
# label: 0
# confidence: 65.386680661295
# label: 0
# confidence: 64.00044573814449
# label: 0
# confidence: 62.95930629576597
# label: 0
# confidence: 62.91134263384562
# label: 0
# confidence: 65.17218320007197
# label: 0
# confidence: 63.931441424283435
# label: 0
# confidence: 63.72532929300434
# label: 0
# confidence: 64.5889694158954
# label: 0
# confidence: 63.08283097315054
# label: 0
# confidence: 63.381507850614895
# label: 0
# confidence: 65.57387116851503
# label: 0
# confidence: 67.02143647205773
# label: 0
# confidence: 67.91549316897631
# label: 0
# confidence: 66.48106200664596
# label: 0
# confidence: 65.41182082733056
# label: 0
# confidence: 65.44230128060747
# label: 0
# confidence: 64.4205912208182
# label: 0
# confidence: 65.70796666671717
# label: 0
# confidence: 64.80859979385545
# label: 0
# confidence: 64.37574173948903
# label: 0
# confidence: 62.75648548477871
# label: 0
# confidence: 66.40999177788584
# label: 1
# confidence: 69.04726262253496
# label: 0
# confidence: 67.66687024073113
# label: 0
# confidence: 65.41731998614922
# label: 0
# confidence: 66.69946253318633
# label: 0
# confidence: 68.68294927305453
# label: 0
# confidence: 68.0791270065864
# label: 0
# confidence: 65.14889479852869
# label: 0
# confidence: 64.93082425161136
# label: 1
# confidence: 63.863018951849924
# label: 1
# confidence: 63.945870972732294
# label: 0
# confidence: 64.64715603376547
# label: 0
# confidence: 66.23293330686788
# label: 0
# confidence: 62.128150126243746
# label: 0
# confidence: 62.941196308344885
# label: 0
# confidence: 63.10070441264666
# label: 0
# confidence: 63.598521432973506
# label: 0
# confidence: 63.40115939845429
# label: 0
# confidence: 65.15053902868647
# label: 0
# confidence: 65.28713876210416
# label: 0
# confidence: 65.00945647803837
# label: 0
# confidence: 63.79864190696551
# label: 0
# confidence: 65.17679489438764
# label: 0
# confidence: 65.96489965924026
# label: 0
# confidence: 64.02034359210091
# label: 0
# confidence: 64.9498176583922
# label: 0
# confidence: 64.61088198352978
# label: 0
# confidence: 68.13407961381402
# label: 1
# confidence: 68.25827045238375
# label: 0
# confidence: 61.89435690697261
# label: 0
# confidence: 62.53308309033694
# label: 0
# confidence: 64.50641668822225
# label: 0
# confidence: 63.48745856099876
# label: 0
# confidence: 64.98461617939948
# label: 0
# confidence: 64.31220757348896
# label: 0
# confidence: 63.9881346777785
# label: 0
# confidence: 63.22970037161754
# label: 0
# confidence: 63.174165840755705
# label: 0
# confidence: 62.00369947444553
# label: 0
# confidence: 63.7192986108836
# label: 0
# confidence: 63.05272156791609
# label: 0
# confidence: 62.90425929214661
# label: 0
# confidence: 63.01741833054618
# label: 0
# confidence: 62.070497229237255
# label: 0
# confidence: 60.58481834513684
# label: 0
# confidence: 61.28397887927289
# label: 0
# confidence: 63.96637189643279
# label: 0
# confidence: 61.59770836269645
# label: 0
# confidence: 61.38148339302851
# label: 0
# confidence: 61.457234468413354
# label: 0
# confidence: 59.78453622579353
# label: 0
# confidence: 62.74966995147298
# label: 0
# confidence: 63.2197652446729
# label: 0
# confidence: 62.73465431832214
# label: 0
# confidence: 63.56084650678974
# label: 0
# <function destroyAllWindows>

# %%
import cv2

cap=cv2.VideoCapture(0)

count = 0
while True:
    ret,test_img=cap.read()
    if not ret :
        continue
    cv2.imwrite("frame%d.jpg" % count, test_img)     # save frame as JPG file
    count += 1
    resized_img = cv2.resize(test_img, (1000, 700))
    cv2.imshow('face detection Tutorial ',resized_img)
    if cv2.waitKey(10) == ord('q'):#wait until 'q' key is pressed
        break


cap.release()
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>
